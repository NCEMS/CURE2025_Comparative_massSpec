# %%
# Colab bootstrap: clone *entire* repo, install deps, set cwd
REPO_URL = "https://github.com/NCEMS/CURE2025_Comparative_massSpec.git"
BRANCH   = "StandAlone_v2.1.1"
TARGET   = "/content/course"

import os, subprocess

if not os.path.exists(TARGET):
    # !git clone --depth 1 -b $BRANCH $REPO_URL $TARGET
else:
    # !git -C $TARGET fetch origin $BRANCH
    # !git -C $TARGET reset --hard origin/$BRANCH

# %cd $TARGET
if os.path.exists("requirements.txt"):
    # !pip -q install -r requirements.txt
    
# !pip install pyteomics

print("Repo ready at:", TARGET, "\nOpen notebooks from the left Files pane.")
